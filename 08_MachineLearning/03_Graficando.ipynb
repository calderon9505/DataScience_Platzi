# %%
from matplotlib import cm # Para manejar colores
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Grafica en 3D
#
# Al graficarlo en un entorno local (No notebook) se genera una vista interactiva. Muy firme!!!

# %%
res = 10
X = np.linspace(-5, 5, res)
Y = np.linspace(-5, 5, res)

# Generar matriz de puntos X, Y
X, Y = np.meshgrid(X, Y)

Z = np.sin(X) + 2*np.sin(Y) 

# Gráficar la superficie
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X, Y, Z, cmap=cm.cool,
                       linewidth=0, antialiased=False)

fig.colorbar(surf)

# %% [markdown]
# ## Curvas de nivel

# %%
fig2,ax2 = plt.subplots()
level_map = np.linspace(np.min(Z), np.max(Z), res) 

# Conout Plot
# cp = ax2.contour(X, Y, Z, levels=level_map,cmap=cm.cool)
cp = ax2.contourf(X, Y, Z, levels=level_map,cmap=cm.cool)

fig2.colorbar(cp)
ax2.set_title('Curvas de nivel')
# plt.show()
# Out:
# Text(0.5, 1.0, 'Curvas de nivel')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b06e2ad7-2e73-4529-91c1-8e44f8b5881a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
