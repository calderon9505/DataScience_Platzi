# %%
import pandas as pd

# %%
eluniversal = pd.read_csv('clean_eluniversal_2022_01_25.csv')
elpais = pd.read_csv('clean_elpais_2022_01_25.csv')

# %%
eluniversal.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count       93.000000      93.000000
# mean         5.301075      25.827957
# std          1.892692      11.951554
# min          2.000000       7.000000
# 25%          4.000000      19.000000
# 50%          6.000000      25.000000
# 75%          7.000000      29.000000
# max          9.000000      91.000000

# %%
elpais.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count       72.000000      72.000000
# mean         7.416667      67.805556
# std          2.684069      22.934468
# min          3.000000      22.000000
# 25%          5.000000      50.750000
# 50%          7.500000      64.000000
# 75%          9.000000      83.000000
# max         15.000000     140.000000

# %%
elpais['n_tokens_title'].plot(style='k.')
eluniversal['n_tokens_title'].plot(style='r.')
# Out:
# <AxesSubplot:>

# %%
elpais['n_tokens_body'].plot(style='k.')
eluniversal['n_tokens_body'].plot(style='r.')
# Out:
# <AxesSubplot:>

# %%
both = pd.concat([eluniversal, elpais])
grouped = both.groupby('newspaper_uid')
grouped.hist()
# Out:
# newspaper_uid
# elpais         [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# eluniversal    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %%
grouped.agg(['min','mean','max'])
# Out:
#               n_tokens_title               n_tokens_body
#                          min      mean max           min       mean  max
# newspaper_uid
# elpais                     3  7.416667  15            22  67.805556  140
# eluniversal                2  5.301075   9             7  25.827957   91

# %%
grouped.plot()
# Out:
# newspaper_uid
# elpais         AxesSubplot(0.125,0.125;0.775x0.755)
# eluniversal    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
