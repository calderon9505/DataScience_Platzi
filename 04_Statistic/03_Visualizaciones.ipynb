# %% [markdown]
# # Diagramas de dispersión

# %%
import pandas as pd
import seaborn as sns

iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.scatterplot.html

# %%
# Scatterplot. Diagramas de dispersion.
sns.scatterplot(data=iris, x='sepal_length', y='petal_length', hue='species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# http://seaborn.pydata.org/generated/seaborn.jointplot.html

# %%
# joint plot
sns.jointplot(data=iris, x='sepal_length', y='petal_length', hue='species')

# %%
# Box plot
sns.boxplot(data = iris, x='species', y='sepal_length')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
# Barplot
sns.barplot(data=iris, x='species', y='sepal_length')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
# comprobación de que barplot escoge la media para graficar
iris.groupby('species')['sepal_length'].mean()
# Out:
# species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal_length, dtype: float64

# %%
from numpy import median
sns.barplot(data=iris, x='species', y='sepal_length', estimator=median)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
iris.groupby('species')['sepal_length'].median()
# Out:
# species
# setosa        5.0
# versicolor    5.9
# virginica     6.5
# Name: sepal_length, dtype: float64

# %%
from numpy import std
sns.barplot(data=iris, x='species', y='sepal_length', estimator=std)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
iris.groupby('species')['sepal_length'].std()
# Out:
# species
# setosa        0.352490
# versicolor    0.516171
# virginica     0.635880
# Name: sepal_length, dtype: float64

# %%
sns.pairplot(iris, hue='species')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b06e2ad7-2e73-4529-91c1-8e44f8b5881a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
